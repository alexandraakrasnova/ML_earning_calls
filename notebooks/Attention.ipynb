# %%
import gensim
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sps
import pickle
import yfinance as yf
import math


from tqdm import tqdm
from gensim.models import KeyedVectors
from datetime import datetime
from collections import Counter

sns.set_style("whitegrid")

# %%
df_train = pd.read_pickle("/content/drive/MyDrive/ML_EPFL_Project/train.pkl")
df_train.head()
# Out:
#                       date      exchange        q ticker  \
# 2980   2020-02-25 00:00:00  NASDAQ: CBRL  2020-Q2   CBRL
# 10025  2019-08-08 00:00:00   NASDAQ: DHC  2019-Q2    DHC
# 2341   2021-04-16 00:00:00     NYSE: CFG  2021-Q1    CFG
# 6733   2019-07-23 00:00:00  NASDAQ: ASTE  2019-Q2   ASTE
# 14835  2022-05-09 00:00:00     NYSE: ESE  2022-Q2    ESE
#
#                                               transcript   daily_r  weekly_r  \
# 2980   prepared remark operator good day welcome crac... -0.054706 -0.151765
# 10025  prepared remark operator good morning welcome ...  0.066991  0.096224
# 2341   prepared remark operator good morning everyone... -0.008828  0.013021
# 6733   prepared remark operator greeting welcome aste... -0.004375  0.020625
# 14835  prepared remark operator good day welcome esco...  0.047190  0.072260
#
#        monthly_r  class
# 2980   -0.500647      5
# 10025   0.058465      1
# 2341    0.104171      3
# 6733   -0.140312      3
# 14835   0.015238      1

# %%
def get_class(x, p1):
    if x >= p1:
      return 2
    elif x <= -p1:
      return 0
    else:
      return 1


df_train['class_d'] = df_train.daily_r.apply(get_class, args=(0.02,))
df_train['class_w'] = df_train.weekly_r.apply(get_class, args=(0.04,))
df_train['class_m'] = df_train.monthly_r.apply(get_class, args=(0.06,))

df_train.head()

# %%
df_train.class_w.hist()
# Out:
# <Axes: >

# %%
token_counts = Counter()
df_train.transcript.apply(lambda x: token_counts.update(x.split(' ')))
# Out:
# 2980     None
# 10025    None
# 2341     None
# 6733     None
# 14835    None
#          ...
# 9829     None
# 15706    None
# 11329    None
# 12758    None
# 8456     None
# Name: transcript, Length: 10586, dtype: object

# %%
min_count = 10
tokens = sorted(t for t, c in token_counts.items() if c >= min_count)
UNK, PAD = "UNK", "PAD"
tokens = [UNK, PAD] + tokens

len(tokens)
# Out:
# 48115

# %%
token_to_id = {w: i for i, w in enumerate(tokens)}

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset
from torch.utils.data import DataLoader


device = 'cuda' if torch.cuda.is_available() else 'cpu'
UNK_IX, PAD_IX = map(token_to_id.get, [UNK, PAD])
TARGET_COLUMN = 'class_w'


def apply_word_dropout(matrix, keep_prop, replace_with=UNK_IX, pad_ix=PAD_IX,):
    dropout_mask = np.random.choice(2, np.shape(matrix), p=[keep_prop, 1 - keep_prop])
    dropout_mask &= matrix != pad_ix
    return np.choose(dropout_mask, [matrix, np.full_like(matrix, replace_with)])


class CustomTranscriptDataset(Dataset):
    def __init__(self, data, max_len, word_dropout=0, device=device):
        self.data = data
        self.max_len = max_len
        self.word_dropout = word_dropout
        self.device = device

    def __len__(self):
        return self.data.shape[0]

    def len(self):
        return self.data.shape[0]

    def get_weights(self):
        class_sample_count = self.data.groupby(by=TARGET_COLUMN).count()['date'].to_numpy()
        weight = 1. / class_sample_count
        sample_weights = np.array([weight[t - 1] for t in self.data[TARGET_COLUMN]])
        return sample_weights

    def __getitem__(self, idx):
        elem = self.data.iloc[idx]
        transcript = np.array([
            token_to_id.get(word, UNK_IX)
            for word in elem['transcript'].split(' ')[:self.max_len]
        ])

        if self.word_dropout != 0:
            transcript = apply_word_dropout(transcript, 1. - self.word_dropout)

        transcript = torch.tensor(
            transcript, device=self.device,
            dtype=torch.int64)
        label = -1

        if TARGET_COLUMN in self.data.columns:
            label = elem[TARGET_COLUMN]

        label = torch.tensor(label, device=device)

        return transcript, label


class MyCollator(object):
    def __init__(self, max_len):
        self.max_len = max_len

    def __call__(self, batch):
        device = batch[0][0].device
        max_sz = np.max([x.shape[0] for x, _ in batch])
        labels = torch.tensor([x for _, x in batch], device=device)

        sz = min(max_sz, self.max_len)
        matrix = torch.full((len(batch), sz), np.int32(PAD_IX), device=device)
        for i in range(len(batch)):
            row_ix = batch[i][0]
            matrix[i, :len(row_ix)] = row_ix[:sz]

        matrix = matrix.clone().detach().to(device=device, dtype=torch.int64)
        return matrix, labels

# %%
class Attention(nn.Module):
    def __init__(self, n_inp, n_hid):
        super().__init__()
        self.Q = nn.Linear(n_inp, 1)
        self.value = nn.Linear(n_inp, n_hid)

        self.lambd = torch.sqrt(torch.tensor(n_inp))

    def forward(self, x):
        scores = self.Q(x) / self.lambd
        atten = nn.Softmax(dim=2)(scores)
        V = self.value(x)

        return torch.bmm(torch.transpose(V, 1, 2), atten).squeeze()


class TranscriptModule(nn.Module):
    def __init__(self, n_tokens=len(tokens), n_filters=128, dropout=0.2,
                 filter_sizes=[3], hid_size=64):
        super().__init__()
        self.emb = nn.Embedding(n_tokens, 256)
        self.atten = Attention(256, 64)

        self.convs = nn.ModuleList([
          nn.Conv1d(
            self.emb.embedding_dim,
            n_filters, fs
          ) for fs in filter_sizes
        ])
        self.fc_conv = nn.Linear((len(filter_sizes) + 1) * n_filters + 64, hid_size)
        self.dropout = nn.Dropout(dropout)

        self.rnn1 = nn.LSTM(self.emb.embedding_dim, n_filters, batch_first=True)
        self.fc_total = nn.Linear(256, hid_size)



    def forward(self, text):
        embedding = self.emb(text)

        atten = self.atten(embedding)
        output, _ = self.rnn1(embedding)
        output = output.permute(0, 2, 1)
        output = F.avg_pool1d(output, output.shape[2]).squeeze(-1)

        embedding = embedding.permute(0, 2, 1)
        conved = [F.relu(conv(embedding)) for conv in self.convs]
        pooled = [F.max_pool1d(conv, conv.shape[2]).squeeze(-1) for conv in conved]
        pooled.append(output)
        pooled.append(atten)

        cat = self.dropout(torch.cat(pooled, dim = 1))
        total = F.relu(self.fc_conv(cat))
        return total


class ClassPredictor(nn.Module):
    def __init__(self, n_tokens=len(tokens), filter_sizes=[3], hid_size=64):
        super().__init__()
        self.transcriptM = TranscriptModule(n_tokens, filter_sizes=filter_sizes, hid_size=hid_size)
        self.fc = nn.Linear(128, 3)

    def forward(self, batch):
        transcript_val = self.transcriptM(batch)
        # return transcript_val
        return self.fc(transcript_val)

    def predict_proba(self, batch):
        ret = self.forward(batch)
        return nn.Softmax(dim=1)(ret)

    def predict_class(self, batch):
        probs = self.predict_proba(batch)
        return probs.argmax(dim=1)

# %%
model = ClassPredictor(filter_sizes=[3, 5, 7, 11], hid_size=128).to(device)
training_data = CustomTranscriptDataset(df_train[:100], max_len=50) #8000
train_dataloader = DataLoader(training_data, batch_size=32, collate_fn=MyCollator(8000), shuffle=True)

batch, labels = next(iter(train_dataloader))
criterion = nn.CrossEntropyLoss()

dummy_pred = model(batch)
dummy_pred.shape
dummy_loss = criterion(dummy_pred, labels)
assert dummy_pred.shape == torch.Size([32, 3])

# %%
from tqdm.auto import tqdm
from IPython.display import clear_output
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


BATCH_SIZE = 32
EPOCHS = 5


def print_metrics(
      model, dataloader,
      histoty_ce,
      batch_size=BATCH_SIZE,
      name="", **kw
    ):
    loss = num_samples = 0.0
    criterion = nn.CrossEntropyLoss(reduction='sum')

    real_labels = []
    pred_labels = []
    model.eval()
    with torch.no_grad():
        for batch, labels in dataloader:
            batch_pred = model(batch)
            loss += criterion(batch_pred, labels)
            num_samples += len(batch_pred)

            pred_labels.extend(model.predict_class(batch).detach().cpu().tolist())
            real_labels.extend(labels.detach().cpu().tolist())

    real_labels = np.array(real_labels)
    pred_labels = np.array(pred_labels)

    cm = confusion_matrix(real_labels, pred_labels)

    stats = pd.DataFrame({
        'label': np.arange(3),
        'occurence': [sum(real_labels==x) for x in range(3)],
        'type': 'real',
    })

    stats = pd.concat([stats, pd.DataFrame({
        'label': np.arange(3),
        'occurence': [sum(pred_labels==x) for x in range(3)],
        'type': 'predicted',
    })])

    loss = loss.detach().cpu().numpy() / num_samples
    histoty_ce.append(loss)

    clear_output()
    print(f"epoch: {len(histoty_ce)}")
    print("%s results:" % (name or ""))
    print("Current CE loss: %.5f" % loss)

    plt.figure(figsize=(20, 6))

    plt.subplot(1, 3, 1)
    plt.plot(histoty_ce)
    plt.xlabel("Iteration")
    plt.ylabel("CE")
    plt.title("Cross Entropy Loss")

    plt.subplot(1, 3, 2)
    sns.barplot(stats, x='label', y='occurence', hue='type')
    plt.title("Distribution of classes")

    plt.subplot(1, 3, 3)
    sns.heatmap(cm, annot=True, fmt='g')
    plt.xlabel("Predicted label")
    plt.ylabel("True label")
    plt.yticks(rotation='horizontal')
    plt.title("Quality of prediction")

    plt.show()

    return loss

# %%
from sklearn.model_selection import train_test_split

data_train, data_val = train_test_split(df_train, test_size=0.1)
# data_train = data_train.iloc[:100]
# data_val = data_val.iloc[:50]

data_train = CustomTranscriptDataset(data_train, max_len=8000) #8000
data_val = CustomTranscriptDataset(data_val, max_len=8000) #8000

data_train.len(), data_val.len()
# Out:
# (9527, 1059)

# %%
def trainModel(model, train_dataloader, val_dataloader, optimizer, criterion, num_epochs=5, batch_size=16, **kw):
    val_err = []
    for epoch in range(num_epochs):
        print(f"epoch: {epoch}")
        model.train()
        for i, cur_batch in tqdm(enumerate(train_dataloader),
                total=len(data_train) // batch_size
            ):
            batch, labels = cur_batch
            pred = model(batch)
            loss = criterion(pred, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # batch.cpu()
            # pred.cpu()
            # loss.cpu()

        print_metrics(
            model, val_dataloader,
            val_err,
            batch_size=batch_size,
            device=device,
            **kw
        )



BATCH_SIZE = 32
EPOCHS = 5

model = ClassPredictor(
    filter_sizes=[3, 4, 5], hid_size=128
).to(device)
criterion = nn.CrossEntropyLoss(reduction='sum')
optimizer = torch.optim.Adam(model.parameters(), lr=1e-6)


sample_weights = data_train.get_weights()
sampler = torch.utils.data.sampler.WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),
    replacement=True)

train_dataloader = DataLoader(data_train, batch_size=32,
                              collate_fn=MyCollator(8000),
                              sampler=sampler)

val_dataloader = DataLoader(data_val, batch_size=32,
                            collate_fn=MyCollator(8000),
                            shuffle=False)


trainModel(model, train_dataloader, val_dataloader,
           optimizer, criterion, batch_size=32, num_epochs=50)
# Out:
# epoch: 50
#  results:
# Current CE loss: 3.10035

# %%
model
# Out:
# ClassPredictor(
#   (transcriptM): TranscriptModule(
#     (emb): Embedding(48115, 256)
#     (atten): Attention(
#       (Q): Linear(in_features=256, out_features=1, bias=True)
#       (value): Linear(in_features=256, out_features=64, bias=True)
#     )
#     (convs): ModuleList(
#       (0): Conv1d(256, 128, kernel_size=(3,), stride=(1,))
#       (1): Conv1d(256, 128, kernel_size=(4,), stride=(1,))
#       (2): Conv1d(256, 128, kernel_size=(5,), stride=(1,))
#     )
#     (fc_conv): Linear(in_features=576, out_features=128, bias=True)
#     (dropout): Dropout(p=0.2, inplace=False)
#     (rnn1): LSTM(256, 128, batch_first=True)
#     (fc_total): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (fc): Linear(in_features=128, out_features=3, bias=True)
# )

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/ML_EPFL_Project/models/attention_v1.pth')

# %%
df_test = pd.read_pickle("/content/drive/MyDrive/ML_EPFL_Project/test.pkl")
df_test.head()
# Out:
#                       date      exchange        q ticker  \
# 5748   2021-07-27 00:00:00  NASDAQ: FELE  2021-Q2   FELE
# 2743   2019-07-02 00:00:00     NYSE: GBX  2019-Q3    GBX
# 16479  2022-05-06 00:00:00     NYSE: GTN  2022-Q1    GTN
# 15556  2021-08-05 00:00:00  NASDAQ: DDOG  2021-Q2   DDOG
# 3413   2021-01-19 00:00:00     NYSE: BAC  2020-Q4    BAC
#
#                                               transcript   daily_r  weekly_r  \
# 5748   prepared remark operator good morning lady gen... -0.006114  0.005258
# 2743   prepared remark operator hello welcome greenbr...  0.027027  0.033514
# 16479  prepared remark operator good day thank standi... -0.068500  0.005000
# 15556  prepared remark operator welcome q2 2021 datad... -0.013826  0.029398
# 3413   prepared remark operator good day everyone wel...  0.008000 -0.064000
#
#        monthly_r
# 5748    0.020543
# 2743   -0.141622
# 16479  -0.088000
# 15556   0.100957
# 3413    0.106769

# %%
data_test = CustomTranscriptDataset(df_test, max_len=8000)
val_dataloader = DataLoader(data_test, batch_size=128,
                            collate_fn=MyCollator(8000),
                            shuffle=False)

classes = []

for batch, _ in tqdm(val_dataloader):
    with torch.no_grad():
        res = model.predict_class(batch).detach().cpu().tolist()
        class_to_coef = {
            0: -1, 1: 0, 2: 1,
        }
        classes.extend([class_to_coef[x] for x in res])
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]

# %%
coefs = pd.DataFrame({
    "alpha": classes
}, index=df_test.index)

coefs.head()
# Out:
#        alpha
# 5748      -1
# 2743       0
# 16479     -1
# 15556      0
# 3413       0

# %%
coefs.to_csv("/content/drive/MyDrive/ML_EPFL_Project/Strategies_coefs/attention_v1.csv")
